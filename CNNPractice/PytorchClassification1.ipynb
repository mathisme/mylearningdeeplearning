# %%
import numpy
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
from torchvision import datasets

# %% [raw]
# I'm going to import the CIFAR dataset.  Here is the class.
#
# torchvision.datasets.CIFAR10(root: Union[str, Path], train: bool = True, transform: Optional[Callable] = None, target_transform: Optional[Callable] = None, download: bool = False)

# %%
training_data = datasets.CIFAR10(root="cfar_data", train=True, download=True)
test_data = datasets.CIFAR10(root="cfar_data", train=False, download=True)
# Out:
# C:\Users\Anned\Desktop\education\Udacity\udacityaimasters\venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
len(training_data)
# Out:
# 50000

# %%
len(test_data)
# Out:
# 10000

# %% [raw]
# I'm going to split the training data into 80%/20% training and validation sets using torch.utils.data.random_split
#
# Here is the function call
# torch.utils.data.random_split(dataset, lengths, generator=<torch._C.Generator object>)
#
# lengths can be a list of fractions that add up to 1 and pytorch will take care of it
# Example of Generator torch.Generator().manual_seed(42)

# %%
training_data, validation_data = torch.utils.data.random_split(training_data, [0.8, 0.2], torch.Generator().manual_seed(42))

# %% [markdown]
# I need to create transforms, 1 for training data, 1 for the validation and test data
